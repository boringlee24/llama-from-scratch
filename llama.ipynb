# %% [markdown]
# # Llama from scratch
#
# I want to provide some tips from my experience implementing a paper. I'm going to cover my tips so far from implementing a dramatically scaled-down version of [Llama](https://arxiv.org/pdf/2302.13971.pdf) for training [TinyShakespeare](https://github.com/karpathy/char-rnn/blob/master/data/tinyshakespeare/input.txt). This post is heavily inspired by Karpathy's [Makemore series](https://www.youtube.com/playlist?list=PLAqhIrjkxbuWI23v9cThsA9GvCAUhRvKZ), which I highly recommend.
#
# I'm only going to *loosely* follow the layout of their paper; while the formatting and order of sections makes sense for publication, we're going to be implementing the paper. I'll also be skipping over some of the more obvious steps, like setting up a virtual environment and installing dependencies.

# %% [markdown]
# A preview of what we're going to end up with:
#
# ```python
#
# print(generate(llama, MASTER_CONFIG, 500)[0])
#
# ZELBETH:
# Sey solmenter! 'tis tonguerered if berryishdd, and What his stabe, you, and, but all I pilJefals, mode with,
# Vurint as steolated have loven OlD the queen'd refore
# Are been, good plmp:
#
# Proforne, wift'es swleen, was no bunderes'd a a quain beath!
# Tybell is my gateer stalk smen'd as be matious dazest brink thou
# lord
# Enves were cIUll, afe and whwas seath This a is, an tale hoice his his onety Meall-tearn not murkawn, fase bettizen'd her,
# To belacquesterer? baxewed wupl usweggs yet tall
# An
# ```

# %% [markdown]
# # Takeaways
#
# ## Always work iteratively: start small, stay certain, and build up.
# My approach for implementing papers is:
# 1. Make all of the helper functions required to test your model quantitatively (data splits, training, plotting the loss).
# 1. Before you even look at the paper, pick a small, simple, and fast model that you've done in the past. Then make a helper function to evaluate the model qualitatively.
# 1. Start by picking apart different components of the paper, and then implementing them one-by-one, training and evaluating as you go.
#
# ## Make sure your layers do what you think.
# 1. Use `.shape` religiously. `assert` and `plt.imshow` are also your friends.
# 1. Work out the results without matrix multiplication first, and then use the `torch` functions to make it efficient after.
# 1. Have a test to see that your layer is right. For example, the RoPE embeddings have a specific property that you can test for. For the Transformer, you can test that the attention is working by looking at the attention map.
# 1. Test your layers on various batch, sequence, and embedding sizes. Even if it works for one size, it might not work for others, which will cause problems at inference time.

# %% [markdown]
# ## About Llama

# %% [markdown]
# Llama is a transformer-based model for language modeling. Meta AI [open-sourced](https://github.com/facebookresearch/llama) Llama this summer, and it's gained a lot of attention (pun intended). When you're reading the introduction, they clearly indicate their goal: make a model that's cheaper for running inference, rather than optimizing training costs.
#
# At this point, we'll just load our libraries and get started.

# %%
import torch
from torch import nn
from torch.nn import functional as F
import numpy as np
from matplotlib import pyplot as plt
import time
import pandas as pd

# %% [markdown]
# ## Setting up our dataset
# While in Llama they train on 1.4T tokens, our dataset TinyShakespeare, the collection of all of Shakespeare's works, is about 1M characters.

# %%
lines = open('./input.txt', 'r').read()

vocab = sorted(list(set(lines)))
itos = {i:ch for i, ch in enumerate(vocab)} # index to string
stoi = {ch:i for i, ch in enumerate(vocab)} # string to index

print(lines[:30])
# Out:
# First Citizen:
# Before we proce

# %% [markdown]
# They use the [SentencePiece](https://github.com/google/sentencepiece) byte-pair encoding tokenizer, but we're going to just use a simple character-level tokenizer.

# %%
# simple tokenization by characters
def encode(s):
    return [stoi[ch] for ch in s]

def decode(l):
    return ''.join([itos[i] for i in l])

print('vocab size:', len(vocab))
decode(encode("hello"))
# Out:
# vocab size: 65
# 'hello'

# %% [markdown]
# Since our dataset is small enough, we don't need to worry about how we store it in memory etc.

# %% [markdown]
# First tip: I'm creating a `config` object that stores some basic model params. It makes our code way more readable and removes constants and magic numbers from the code. I'm not going to use types, as  I want to keep things flexible for now and be able to add more parameters later on.

# %%
MASTER_CONFIG = {
    "vocab_size": len(vocab),
}
MASTER_CONFIG
# Out:
# {'vocab_size': 65}

# %%
dataset = torch.tensor(encode(lines), dtype=torch.int8)
dataset.shape, dataset
# Out:
# (torch.Size([1115394]),
#  tensor([18, 47, 56,  ..., 45,  8,  0], dtype=torch.int8))

# %% [markdown]
# Let's create a method to generate our training data and labels for batches. We'll use the same method for validation and test data. Note that I like to test my functions in the same block that I define them, just to make sure they work as expected before moving on.

# %%
def get_batches(data, split, batch_size, context_window, config=MASTER_CONFIG):
    train = data[:int(.8 * len(data))]
    val = data[int(.8 * len(data)): int(.9 * len(data))]
    test = data[int(.9 * len(data)):]
    
    batch_data = train
    if split == 'val':
        batch_data = val

    if split == 'test':
        batch_data = test
    
    # pick random starting points
    ix = torch.randint(0, batch_data.size(0) - context_window - 1, (batch_size,))
    x = torch.stack([batch_data[i:i+context_window] for i in ix]).long()
    y = torch.stack([batch_data[i+1:i+context_window+1] for i in ix]).long() # y is x shifted by 1 for self-supervised training
    return x, y

MASTER_CONFIG.update({
    'batch_size': 8,
    'context_window': 16
})

xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])

[(decode(xs[i].tolist()), decode(ys[i].tolist())) for i in range(len(xs))]
# Out:
# [('\nWere not so ric', 'Were not so rich'),
#  ('n Bohemia can\nle', ' Bohemia can\nlea'),
#  ('he drops booties', 'e drops booties '),
#  ('me speak.\n\nAll:\n', 'e speak.\n\nAll:\nS'),
#  ('ATESBY:\nI go.\n\nR', 'TESBY:\nI go.\n\nRA'),
#  ('he sequel hangs ', 'e sequel hangs t'),
#  ('als of his sacre', 'ls of his sacred'),
#  ('t,\nWith them Sir', ',\nWith them Sir ')]

# %% [markdown]
# What's interesting about implementing papers is that there are two aspects to the model *working*: compilation (do your tensors all match up from layer to layer), and training (does the loss go down). Figuring out how to ensure that each of your compoenents is working is key to developing your model in a predictable, engineering-minded way.
#
# That's why we're also going to define the method for how we're going to evaluate the model. We want to do this before we even define the model, because we want to be able to use it to evaluate the model as we're training it.

# %%
@torch.no_grad()  # don't compute gradients for this function
def evaluate_loss(model, config=MASTER_CONFIG): # evaluate training and validation loss
    out = {}
    model.eval()
    device = next(model.parameters()).device
    for split in ["train", "val"]:
        losses = []
        for _ in range(10):
            xb, yb = get_batches(dataset, split, config['batch_size'], config['context_window'])
            xb, yb = xb.to(device), yb.to(device)
            _, loss = model(xb, yb)
            losses.append(loss.item())
        out[split] = np.mean(losses)
    model.train()
    return out

# %% [markdown]
# ## Setting up a working base model

# %% [markdown]
# Here's a basic feed-forward neural network with embeddings. It's the base model we're going to start with, and then swap out parts of it as we go along until we eventually end up with the model as described in Llama.

# %%
MASTER_CONFIG
# Out:
# {'vocab_size': 65, 'batch_size': 8, 'context_window': 16}

# %%
class SimpleBrokenModel(nn.Module):
    def __init__(self, config=MASTER_CONFIG):
        super().__init__()
        self.config = config

        self.embedding = nn.Embedding(config['vocab_size'], config['d_model']) # map from index of word in vocab to its embedding (a vector of size d_model)
        self.linear = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            nn.ReLU(),
            nn.Linear(config['d_model'], config['vocab_size']), # output will map to every char in vocab, representing probability of that char being next
        )

        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embedding(idx) # dimension: batch_size x context_window (8 x 16) -> batch_size x context_window x d_model (8 x 16 x 128)
        a = self.linear(x) # dimension: batch_size x context_window x d_model -> batch_size x context_window x vocab_size (8 x 16 x 65)
        logits = F.softmax(a, dim=-1) # 8 x 16 x 65

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1)) # logits: 128 x 65, targets: 128
            return logits, loss

        else:
            return logits

MASTER_CONFIG.update({
    'd_model': 128,
})
model = SimpleBrokenModel(MASTER_CONFIG)
xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])

logits, loss = model(xs, ys)
# Out:
# model params: 33217

# %% [markdown]
# It's at this point that we have to start worrying about the shape of our tensors and making indices match. Check out this line of our model definition:
#
# ```python
# loss = F.cross_entropy(logits.view(-1, config['vocab_size']), targets.view(-1))
# ```
#
# We have to reshape the `logits` and `targets` tensors so that their dimensions match when we compare. We do this with the `view` method. The `-1` argument means "infer this dimension from the others". So, in this case, we're saying "reshape `logits` and `targets` to have the same number of rows, and however many columns are needed to make that happen". This is a common pattern when you're working with batches of data.

# %% [markdown]
# Alright, let's train our `SimpleBrokenModel` to make sure gradients flow. After we confirm that, we can swap out parts of it to match Llama, train again, and track our progress. It's at this point that I start keeping a *log* of my training runs, so that I can easily just go back to a previous run in the event that I mess something up.

# %%
MASTER_CONFIG.update({
    'epochs': 1000,
    'log_interval': 10,
    'batch_size': 32,
})
model = SimpleBrokenModel(MASTER_CONFIG).to('cuda')

optimizer = torch.optim.Adam(
    model.parameters(), 
)

def train(model, optimizer, scheduler=None, config=MASTER_CONFIG, print_logs=False):
    losses = []
    start_time = time.time()
    for epoch in range(config['epochs']):
        optimizer.zero_grad()
        
        xs, ys = get_batches(dataset, 'train', config['batch_size'], config['context_window'])
        xs, ys = xs.to('cuda'), ys.to('cuda')
        logits, loss = model(xs, targets=ys)
        loss.backward()
        optimizer.step()
        
        if scheduler:
            scheduler.step()
        
        if epoch % config['log_interval'] == 0:
            batch_time = time.time() - start_time
            x = evaluate_loss(model)
            losses += [x]
            if print_logs:
                print(f"Epoch {epoch} | val loss {x['val']:.3f} | Time {batch_time:.3f} | ETA in seconds {batch_time * (config['epochs'] - epoch)/config['log_interval'] :.3f}")
            start_time = time.time()

            if scheduler:
                print("lr: ", scheduler.get_lr())

    print("validation loss: ", losses[-1]['val'])
    return pd.DataFrame(losses).plot()

train(model, optimizer, print_logs=True)
# Out:
# model params: 33217
# Epoch 0 | val loss 4.173 | Time 0.003 | ETA in seconds 0.322
# Epoch 10 | val loss 4.156 | Time 0.020 | ETA in seconds 1.998
# Epoch 20 | val loss 4.108 | Time 0.020 | ETA in seconds 1.993
# Epoch 30 | val loss 4.051 | Time 0.020 | ETA in seconds 1.960
# Epoch 40 | val loss 4.018 | Time 0.020 | ETA in seconds 1.935
# Epoch 50 | val loss 3.986 | Time 0.020 | ETA in seconds 1.934
# Epoch 60 | val loss 3.974 | Time 0.021 | ETA in seconds 1.964
# Epoch 70 | val loss 3.963 | Time 0.020 | ETA in seconds 1.892
# Epoch 80 | val loss 3.963 | Time 0.020 | ETA in seconds 1.868
# Epoch 90 | val loss 3.962 | Time 0.021 | ETA in seconds 1.893
# Epoch 100 | val loss 3.952 | Time 0.020 | ETA in seconds 1.837
# Epoch 110 | val loss 3.951 | Time 0.020 | ETA in seconds 1.802
# Epoch 120 | val loss 3.951 | Time 0.022 | ETA in seconds 1.918
# Epoch 130 | val loss 3.960 | Time 0.020 | ETA in seconds 1.753
# Epoch 140 | val loss 3.951 | Time 0.020 | ETA in seconds 1.747
# Epoch 150 | val loss 3.956 | Time 0.020 | ETA in seconds 1.732
# Epoch 160 | val loss 3.949 | Time 0.024 | ETA in seconds 2.031
# Epoch 170 | val loss 3.944 | Time 0.020 | ETA in seconds 1.689
# Epoch 180 | val loss 3.951 | Time 0.020 | ETA in seconds 1.657
# Epoch 190 | val loss 3.959 | Time 0.020 | ETA in seconds 1.627
# Epoch 200 | val loss 3.955 | Time 0.021 | ETA in seconds 1.653
# Epoch 210 | val loss 3.944 | Time 0.020 | ETA in seconds 1.585
# Epoch 220 | val loss 3.946 | Time 0.020 | ETA in seconds 1.572
# Epoch 230 | val loss 3.940 | Time 0.020 | ETA in seconds 1.575
# Epoch 240 | val loss 3.939 | Time 0.020 | ETA in seconds 1.543
# Epoch 250 | val loss 3.938 | Time 0.021 | ETA in seconds 1.542
# Epoch 260 | val loss 3.939 | Time 0.020 | ETA in seconds 1.493
# Epoch 270 | val loss 3.944 | Time 0.020 | ETA in seconds 1.474
# Epoch 280 | val loss 3.955 | Time 0.020 | ETA in seconds 1.473
# Epoch 290 | val loss 3.949 | Time 0.020 | ETA in seconds 1.443
# Epoch 300 | val loss 3.942 | Time 0.020 | ETA in seconds 1.415
# Epoch 310 | val loss 3.947 | Time 0.020 | ETA in seconds 1.380
# Epoch 320 | val loss 3.948 | Time 0.020 | ETA in seconds 1.381
# Epoch 330 | val loss 3.951 | Time 0.020 | ETA in seconds 1.345
# Epoch 340 | val loss 3.948 | Time 0.020 | ETA in seconds 1.339
# Epoch 350 | val loss 3.944 | Time 0.020 | ETA in seconds 1.314
# Epoch 360 | val loss 3.955 | Time 0.020 | ETA in seconds 1.306
# Epoch 370 | val loss 3.958 | Time 0.020 | ETA in seconds 1.285
# Epoch 380 | val loss 3.937 | Time 0.021 | ETA in seconds 1.273
# Epoch 390 | val loss 3.947 | Time 0.020 | ETA in seconds 1.231
# Epoch 400 | val loss 3.949 | Time 0.020 | ETA in seconds 1.224
# Epoch 410 | val loss 3.951 | Time 0.020 | ETA in seconds 1.199
# Epoch 420 | val loss 3.940 | Time 0.020 | ETA in seconds 1.180
# Epoch 430 | val loss 3.950 | Time 0.020 | ETA in seconds 1.156
# Epoch 440 | val loss 3.944 | Time 0.020 | ETA in seconds 1.121
# Epoch 450 | val loss 3.957 | Time 0.021 | ETA in seconds 1.157
# Epoch 460 | val loss 3.949 | Time 0.020 | ETA in seconds 1.092
# Epoch 470 | val loss 3.950 | Time 0.020 | ETA in seconds 1.066
# Epoch 480 | val loss 3.949 | Time 0.021 | ETA in seconds 1.072
# Epoch 490 | val loss 3.955 | Time 0.020 | ETA in seconds 1.027
# Epoch 500 | val loss 3.956 | Time 0.020 | ETA in seconds 1.008
# Epoch 510 | val loss 3.949 | Time 0.021 | ETA in seconds 1.052
# Epoch 520 | val loss 3.952 | Time 0.020 | ETA in seconds 0.970
# Epoch 530 | val loss 3.955 | Time 0.020 | ETA in seconds 0.955
# Epoch 540 | val loss 3.940 | Time 0.020 | ETA in seconds 0.922
# Epoch 550 | val loss 3.947 | Time 0.024 | ETA in seconds 1.093
# Epoch 560 | val loss 3.950 | Time 0.020 | ETA in seconds 0.888
# Epoch 570 | val loss 3.946 | Time 0.020 | ETA in seconds 0.869
# Epoch 580 | val loss 3.947 | Time 0.020 | ETA in seconds 0.857
# Epoch 590 | val loss 3.934 | Time 0.020 | ETA in seconds 0.829
# Epoch 600 | val loss 3.951 | Time 0.020 | ETA in seconds 0.811
# Epoch 610 | val loss 3.943 | Time 0.021 | ETA in seconds 0.803
# Epoch 620 | val loss 3.956 | Time 0.020 | ETA in seconds 0.760
# Epoch 630 | val loss 3.945 | Time 0.020 | ETA in seconds 0.745
# Epoch 640 | val loss 3.949 | Time 0.020 | ETA in seconds 0.720
# Epoch 650 | val loss 3.948 | Time 0.021 | ETA in seconds 0.724
# Epoch 660 | val loss 3.939 | Time 0.020 | ETA in seconds 0.693
# Epoch 670 | val loss 3.944 | Time 0.020 | ETA in seconds 0.664
# Epoch 680 | val loss 3.959 | Time 0.020 | ETA in seconds 0.647
# Epoch 690 | val loss 3.932 | Time 0.020 | ETA in seconds 0.627
# Epoch 700 | val loss 3.955 | Time 0.020 | ETA in seconds 0.607
# Epoch 710 | val loss 3.948 | Time 0.020 | ETA in seconds 0.583
# Epoch 720 | val loss 3.949 | Time 0.021 | ETA in seconds 0.575
# Epoch 730 | val loss 3.948 | Time 0.020 | ETA in seconds 0.540
# Epoch 740 | val loss 3.939 | Time 0.020 | ETA in seconds 0.522
# Epoch 750 | val loss 3.952 | Time 0.020 | ETA in seconds 0.508
# Epoch 760 | val loss 3.947 | Time 0.020 | ETA in seconds 0.482
# Epoch 770 | val loss 3.940 | Time 0.020 | ETA in seconds 0.460
# Epoch 780 | val loss 3.946 | Time 0.020 | ETA in seconds 0.440
# Epoch 790 | val loss 3.943 | Time 0.020 | ETA in seconds 0.424
# Epoch 800 | val loss 3.951 | Time 0.020 | ETA in seconds 0.404
# Epoch 810 | val loss 3.941 | Time 0.020 | ETA in seconds 0.381
# Epoch 820 | val loss 3.946 | Time 0.021 | ETA in seconds 0.370
# Epoch 830 | val loss 3.949 | Time 0.020 | ETA in seconds 0.346
# Epoch 840 | val loss 3.951 | Time 0.020 | ETA in seconds 0.319
# Epoch 850 | val loss 3.953 | Time 0.020 | ETA in seconds 0.301
# Epoch 860 | val loss 3.941 | Time 0.020 | ETA in seconds 0.280
# Epoch 870 | val loss 3.944 | Time 0.020 | ETA in seconds 0.261
# Epoch 880 | val loss 3.951 | Time 0.022 | ETA in seconds 0.260
# Epoch 890 | val loss 3.942 | Time 0.020 | ETA in seconds 0.220
# Epoch 900 | val loss 3.954 | Time 0.020 | ETA in seconds 0.202
# Epoch 910 | val loss 3.939 | Time 0.020 | ETA in seconds 0.179
# Epoch 920 | val loss 3.941 | Time 0.024 | ETA in seconds 0.191
# Epoch 930 | val loss 3.946 | Time 0.020 | ETA in seconds 0.142
# Epoch 940 | val loss 3.946 | Time 0.020 | ETA in seconds 0.120
# Epoch 950 | val loss 3.947 | Time 0.020 | ETA in seconds 0.101
# Epoch 960 | val loss 3.948 | Time 0.020 | ETA in seconds 0.080
# Epoch 970 | val loss 3.948 | Time 0.020 | ETA in seconds 0.060
# Epoch 980 | val loss 3.938 | Time 0.020 | ETA in seconds 0.041
# Epoch 990 | val loss 3.944 | Time 0.020 | ETA in seconds 0.020
# validation loss:  3.9440457582473756
# <Axes: >

# %% [markdown]
# Notice how we get a training curve that goes down, but barely by anything. How do we know it's barely training? We have to use first principles. The cross-entropy loss before training is 4.17, and after 1000 epochs is 3.93. How can we make sense of it intuitively?
#
# Cross-entropy in this context is referring to how likely we are to pick the wrong word. So here,
#
# $$
# H(T, q) = - \sum_{i = 1}^{N} \frac{1}{N} \log q(x_i)
# $$
#
# where $q(x_i)$ is the probability of picking the right word, as estimated by the model. If $q(x_i)$ is close to 1, then $\log q$ is close to 0; similarly, if $q$ is small, then $\log q$ is a large negative number, so $-\log q$ will be a large positive number. Now to build the intuition: to start, $-\log q = 4.17$, so $q = 0.015$, or around $\frac{1}{64.715}$. Recall that the vocabulary size $|V| = 65$, so what we're basically saying here is that the model is as good at choosing the next letter as randomly picking from our vocabulary. After training, $-\log q = 3.93$, so we're now basically choosing between 50 letters. This is a very small improvement, so something is probably wrong.
#
# To get an intuition for how the loss relates to the model's performance, think about the model choosing among $\tilde V$ tokens; when $\tilde V$ is small, the model is more likely to guess right. In addition, we know $\max \tilde V = V$, which can help us understand if our model is learning at all.
#
# $$\tilde V = \exp(L)$$
#
# Let's try to debug what's going on. Notice that in our model we're using a softmax layer on our logits, which is a function that takes a vector of numbers and squashes them into a probability distribution. But for using the built in `F.cross_entropy` function, we need to pass in the [unnormalized logits directly](https://pytorch.org/docs/stable/generated/torch.nn.functional.cross_entropy.html). So let's remove that from our model and try again.

# %%
# class SimpleBrokenModel(nn.Module):
#     def __init__(self, config=MASTER_CONFIG):
#         super().__init__()
#         self.config = config

#         self.embedding = nn.Embedding(config['vocab_size'], config['d_model']) # map from index of word in vocab to its embedding (a vector of size d_model)
#         self.linear = nn.Sequential(
#             nn.Linear(config['d_model'], config['d_model']),
#             nn.ReLU(),
#             nn.Linear(config['d_model'], config['vocab_size']), # output will map to every char in vocab, representing probability of that char being next
#         )

#         print("model params:", sum([m.numel() for m in self.parameters()]))

#     def forward(self, idx, targets=None):
#         x = self.embedding(idx) # dimension: batch_size x context_window (8 x 16) -> batch_size x context_window x d_model (8 x 16 x 128)
#         a = self.linear(x) # dimension: batch_size x context_window x d_model -> batch_size x context_window x vocab_size (8 x 16 x 65)
#         logits = F.softmax(a, dim=-1) # 8 x 16 x 65

#         if targets is not None:
#             loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1)) # logits: 128 x 65, targets: 128
#             return logits, loss

#         else:
#             return logits

class SimpleModel(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.embedding = nn.Embedding(config['vocab_size'], config['d_model'])
        self.linear = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            nn.ReLU(),
            nn.Linear(config['d_model'], config['vocab_size']),
        )

        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        logits = self.linear(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1))
            return logits, loss

        else:
            return logits

model = SimpleModel(MASTER_CONFIG).to('cuda')
xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])
xs, ys = xs.to('cuda'), ys.to('cuda')

logits, loss = model(xs, ys)
optimizer = torch.optim.Adam(model.parameters())
train(model, optimizer)
# Out:
# model params: 33217
# validation loss:  2.523336887359619
# <Axes: >

# %% [markdown]
# Great, now our loss is $2.54$, so we're choosing from $12.67$ characters. That's way better than the 65 we started with. Let's add a generate method to our model so we visually see the results of our model.

# %%
def generate(model, config=MASTER_CONFIG, max_new_tokens=30):
    idx = torch.zeros(5, 1).long().to('cuda')  # 5 sequences, 1 token each
    for _ in range(max_new_tokens):
        # call the model
        logits = model(idx[:, -config['context_window']:])
        last_time_step_logits = logits[
            :, -1, :
        ]  # all the batches (1), last time step, all the logits
        p = F.softmax(last_time_step_logits, dim=-1)  # softmax to get probabilities
        idx_next = torch.multinomial(
            p, num_samples=1
        )  # sample from the distribution to get the next token
        idx = torch.cat([idx, idx_next], dim=-1)  # append to the sequence
    return [decode(x) for x in idx.tolist()]

generate(model)
# Out:
# ['\n\nMNof d as lanet Womatonvegrt ',
#  "\nSo oor's:\n\nY siged,\nDecol, bes",
#  '\nWeesl br mpeey wivead! ls bama',
#  '\nWathatind helle:\nWhen,\nll.\nARG',
#  "\n\nS: Ro t a sind ad, n'sp Hath\n"]

# %% [markdown]
# It's not half bad, but also not half good. But now we have a working model that is training to a validation loss. So here we'll iterate on our model to make it closer to Llama.

# %% [markdown]
# ## Llama specifics
# Llama describes three architectural modifications to the original Transformer:
# 1. RMSNorm for pre-normalization
# 1. Rotary embeddings
# 1. SwiGLU activation function
#
# We're going to add each one, one at a time to our base model, and iterate.

# %% [markdown]
# ### RMSNorm
#
# In Vaswani 2017, the original transformer uses BatchNormalization. In Llama, the authors use RMSNorm, which is where you scale the vector by the variance without centering it. In addition, while Vaswani applies normalization to the output of the attention layer (post-normalization), Llama applies it to the inputs before (pre-normalization).

# %%
class RMSNorm(nn.Module):
    def __init__(self, layer_shape, eps=1e-8, bias=False):
        super(RMSNorm, self).__init__()
        self.register_parameter("scale", nn.Parameter(torch.ones(layer_shape)))

    def forward(self, x):
        """
        assumes shape is (batch, seq_len, d_model)
        """
        # frob norm is not the same as RMS. RMS = 1/sqrt(N) * frob norm
        ff_rms = torch.linalg.norm(x, dim=(1,2)) * x[0].numel() ** -.5
        raw = x / ff_rms.unsqueeze(-1).unsqueeze(-1)
        return self.scale[:x.shape[1], :].unsqueeze(0) * raw

config = {
    'batch_size': 5,
    'context_window': 11,
    'd_model': 13,
}
batch = torch.randn((config['batch_size'], config['context_window'], config['d_model']))
m = RMSNorm((config['context_window'], config['d_model']))
g = m(batch)
print(g.shape)
# Out:
# torch.Size([5, 11, 13])

# %% [markdown]
# We want to test to ensure that the RMSNorm is doing what we think it should. We can do this the old-fashioned way: row-wise comparisons. The RMSNorm has the property where the norm of the layer will be the square root of the number of elements in the layer, so we can check that for every layer.

# %%
rms = torch.linalg.norm(batch, dim=(1,2)) * (batch[0].numel() ** -.5)

# scaled_batch.var(dim=(1,2))
assert torch.linalg.norm( torch.arange(5).float() ) == (torch.arange(5).float() ** 2 ).sum() ** .5
rms = torch.linalg.norm( torch.arange(5).float() ) * (torch.arange(5).numel() ** -.5)
assert torch.allclose(torch.linalg.norm(torch.arange(5).float() / rms), torch.tensor(5 ** .5))
ff_rms = torch.linalg.norm(batch, dim=(1,2)) * batch.shape[1:].numel() ** -.5

# RMS for sure
ffx = torch.zeros_like(batch)
for i in range(batch.shape[0]):
    ffx[i] = batch[i] / ff_rms[i]
assert torch.allclose(torch.linalg.norm(ffx, dim=(1,2)) ** 2, torch.tensor(143).float())
assert torch.allclose(ffx, g)

# %% [markdown]
# Alright, so that's RMSNorm, and it seems like it's working. Again, let's test it out.

# %%
class SimpleModel_RMS(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.embedding = nn.Embedding(config['vocab_size'], config['d_model'])
        self.rms = RMSNorm((config['context_window'], config['d_model']))
        self.linear = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            nn.ReLU(),
            nn.Linear(config['d_model'], config['vocab_size']),
        )

        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        x = self.rms(x) # rms pre-normalization, does not change dimension. still batch size x context window x d_model
        logits = self.linear(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1))
            return logits, loss

        else:
            return logits

model = SimpleModel_RMS(MASTER_CONFIG).to('cuda')
xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])
xs, ys = xs.to('cuda'), ys.to('cuda')
logits, loss = model(xs, ys)
optimizer = torch.optim.Adam(model.parameters())
train(model, optimizer)
# Out:
# model params: 35265
# validation loss:  2.494206953048706
# <Axes: >

# %% [markdown]
# So RMSNorm works, and it got our loss down by a small amount.

# %% [markdown]
# ### Rotary Embeddings
# [RoPE](https://arxiv.org/pdf/2104.09864.pdf) is a kind of positional encoding for transformers. In Attention is All You Need, the authors propose two kinds of positional encodings, learned and fixed. In RoPE, the authors propose embedding the position of a token in a sequence by rotating the embedding, with a different rotation at each position.

# %%
def get_rotary_matrix(context_window, embedding_dim):
    R = torch.zeros((context_window, embedding_dim, embedding_dim), requires_grad=False)
    for position in range(context_window):
        for i in range(embedding_dim//2):
            theta = 10000. ** (-2.*(i - 1) / embedding_dim)
            m_theta = position * theta
            R[position, 2*i,2*i] = np.cos(m_theta)
            R[position, 2*i,2*i+1] = - np.sin(m_theta)
            R[position, 2*i+1,2*i] = np.sin(m_theta)
            R[position, 2*i+1,2*i+1] = np.cos(m_theta)
    return R

# %%
K = 3
config = {
    'batch_size': 10,
    'd_model': 32,
    'n_heads': 8,
    'context_window': K**2,
}
batch = torch.randn(1, config['context_window'], config['d_model'])
R = get_rotary_matrix(config['context_window'], config['d_model'])
fig, ax = plt.subplots(K, K, figsize=(K * 3, K * 4))

for i in range(K):
    for j in range(K):
        ax[i, j].imshow(R[i * K + j, :, :].detach().numpy())
        ax[i, j].set_title(f'rotation at {i * K + j}')

# %% [markdown]
# Let's make sure these work. They should exhibit the quality that
# $$
# q_m^T k_n = (R^d_{\Theta, m}W_q x_m)^T (R^d_{\Theta, n} W_k x_n) = x^T W_q R^d_{\Theta, n-m} W_k x_n.
# $$

# %%
config = {
    'd_model': 128,
    'context_window': 16,
}

R = get_rotary_matrix(config['context_window'], config['d_model']) # shape: context_window x d_model x d_model
x = torch.randn(config['d_model']) # 128 vector
y = torch.randn(config['d_model'])

m = 3
n = 13

x_m = R[m,:,:] @ x # position encoded x at position m, x_m is size 128 vector
x_n = R[n,:,:] @ y

assert torch.isclose(x_m @ x_n, x @ R[n-m,:,:] @ y)

# %% [markdown]
# So the RoPE rotations work as expected.

# %%
config = {
    'batch_size': 10,
    'd_model': 512,
    'n_heads': 8,
    'context_window': 16,
}

class RoPEAttentionHead(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.w_q = nn.Linear(config['d_model'], config['d_model'], bias=False)
        self.w_k = nn.Linear(config['d_model'], config['d_model'], bias=False)
        self.w_v = nn.Linear(config['d_model'], config['d_model'], bias=False)

        self.R = get_rotary_matrix(config['context_window'], config['d_model'])

    def get_rotary_matrix(context_window, embedding_dim):
        R = torch.zeros((context_window, embedding_dim, embedding_dim), requires_grad=False)
        for position in range(context_window):
            for i in range(embedding_dim//2):
                theta = 10000. ** (-2.*(i - 1) / embedding_dim)
                m_theta = position * theta
                R[position, 2*i,2*i] = np.cos(m_theta)
                R[position, 2*i,2*i+1] = - np.sin(m_theta)
                R[position, 2*i+1,2*i] = np.sin(m_theta)
                R[position, 2*i+1,2*i+1] = np.cos(m_theta)
        return R
    
    def forward(self, x, return_attn_weights=False):
        self.R = self.R.to(x.device)
        b,m,d = x.shape
        
        q = self.w_q(x) # batch_size x context_window x d_model
        k = self.w_k(x)
        v = self.w_v(x)

        q_rotated = (torch.bmm(q.transpose(0,1), self.R[:m])).transpose(0,1)
        k_rotated = (torch.bmm(k.transpose(0,1), self.R[:m])).transpose(0,1)

        activations = F.scaled_dot_product_attention(
            q_rotated,k_rotated,v,dropout_p =.1
        ) # batch_size x context_window x d_model

        if return_attn_weights:
            attn_weights = torch.bmm(q_rotated, k_rotated.transpose(1,2)) / np.sqrt(d)
            attn_weights = F.softmax(attn_weights, dim=-1) # batch_size x context_window x context_window (attention score between each token and every other token)
            return activations, attn_weights
        return activations

layer = RoPEAttentionHead(config)
batch = torch.randn((config['batch_size'], config['context_window'], config['d_model']))
output, attn_weights = layer(batch, return_attn_weights=True)

# %% [markdown]
# > Tip here: know the difference between tensor dimensions at train time vs tensor dimensions at inference time.
#
# Although at train time, you can expect your tensor dimensions to match your model parameters closely, eg `batch.shape = (config['batch_size'], config['context_window'], config['d_model'])`, at inference time, you may have to deal with a single example, eg `batch.shape = (1, 1, config['d_model'])`. For this reason, you need to make sure that when you're indexing in the `forward` pass, you're indexing using shapes derived from the input, not necessarily the model parameters.

# %% [markdown]
# Let's make sure it does what we think it does. For this layer, we're going to want to test three things:
# 1. that it rotates embeddings the way we think it does
# 2. that the attention mask used for causal attention is working properly.

# %%
x = torch.randn((config['batch_size'], config['context_window'], config['d_model']))

q = layer.w_q(x)
k = layer.w_k(x)
v = layer.w_v(x)

q_rotated = torch.zeros_like(x)
k_rotated = torch.zeros_like(x)
v_rotated = torch.zeros_like(x)

for position in range(config['context_window']):
    q_rotated[:,position,:] = torch.matmul(q[:,position,:], layer.R[position,:,:])
    k_rotated[:,position,:] = torch.matmul(k[:,position,:], layer.R[position,:,:])
    v_rotated[:,position,:] = torch.matmul(v[:,position,:], layer.R[position,:,:])

q_rotated = (torch.bmm(q.transpose(0,1), layer.R)).transpose(0,1)
k_rotated = (torch.bmm(k.transpose(0,1), layer.R)).transpose(0,1)
v_out = (torch.bmm(v.transpose(0,1), layer.R)).transpose(0,1)

assert torch.allclose(q.transpose(0,1)[0], q[:,0,:])
assert torch.allclose(q.transpose(0,1)[0] @ layer.R[0], q[:,0,:] @ layer.R[0])
assert torch.allclose(q_rotated, q_rotated)

# %%
config = {
    'batch_size': 1,
    'd_model': 2,
    'n_heads': 2,
    'context_window': 3,
}

layer = RoPEAttentionHead(config)
batch = torch.ones((config['batch_size'], config['context_window'], config['d_model']))
output, attn_weights = layer(batch, return_attn_weights=True)

m = 0
x_q = batch[0, m]
q = layer.R[m,:,:] @ layer.w_q(x_q)

assert torch.allclose(layer.w_q(x_q), layer.w_q.weight @ x_q)
assert torch.allclose(q, layer.R[m, :, :] @ layer.w_q.weight @ x_q)

n = 2
x_k = batch[0, n]
k = layer.R[n,:,:] @ layer.w_k(x_k)

assert torch.allclose(layer.w_k(x_k), layer.w_k.weight @ x_k)
assert torch.allclose(k, layer.R[n, :, :] @ layer.w_k.weight @ x_k)

assert q.T @ k == q @ k # transpose is redundant
assert torch.allclose(q @ k, x_k.T @ layer.w_k.weight.T @ layer.R[n, :, :].T @ layer.R[m, :, :] @ layer.w_q.weight @ x_q)
assert torch.allclose(q @ k, x_k.T @ layer.w_k.weight.T @ layer.R[n-m, :, :].T @ layer.w_q.weight @ x_q)

# %% [markdown]
# Let's setup a multi-headed attention layer for this singular attention head and see what happens when we train.

# %%
# definitely there's an optimization we could make where we cache the rotation matrices, but skip.
class RoPEMultiheadAttention(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.heads = nn.ModuleList([
            RoPEAttentionHead(config) for _ in range(config['n_heads'])
        ])
        self.linear = nn.Linear(config['n_heads'] * config['d_model'], config['d_model'])
        self.dropout = nn.Dropout(.1)

    def forward(self, x):
        heads = [h(x) for h in self.heads]
        x = torch.cat(heads, dim=-1)
        x = self.linear(x)
        x = self.dropout(x)
        return x
    
MASTER_CONFIG.update({
    'n_heads': 8,
})
layer = RoPEMultiheadAttention(MASTER_CONFIG)
batch = torch.ones((MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'], MASTER_CONFIG['d_model'])) # 32 x 16 x 128
output = layer(batch) # 32 x 16 x 128
output.shape
# Out:
# torch.Size([32, 16, 128])

# %%
class RopeModel(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.embedding = nn.Embedding(config['vocab_size'], config['d_model'])
        self.rms = RMSNorm((config['context_window'], config['d_model']))
        self.rope_attention = RoPEMultiheadAttention(config)

        self.linear = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            nn.ReLU(),
        )

        self.last_linear = nn.Linear(config['d_model'], config['vocab_size'])
        
        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        
        # one block of attention
        x = self.rms(x) # rms pre-normalization
        x = x + self.rope_attention(x)

        x = self.rms(x) # rms pre-normalization
        x = x + self.linear(x)

        logits = self.last_linear(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1))
            return logits, loss

        else:
            return logits

model = RopeModel(MASTER_CONFIG).to('cuda')
xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])
xs, ys = xs.to('cuda'), ys.to('cuda')
logits, loss = model(xs, ys)
optimizer = torch.optim.Adam(model.parameters())
train(model, optimizer)
# Out:
# model params: 559681
# validation loss:  0.17266630679368972
# <Axes: >

# %% [markdown]
# Wow, would you look at that, our validation loss is down to .16. That is so low...it's almost too low. Consider the check we used from above: $\exp(.16) = 1.17$, so it's as if the model is choosing basically next character correctly every time. Let's see what happens when we generate.

# %%
generate(model, config=MASTER_CONFIG)
# Out:
# ['\nEEEEEEEERRRRRRRRRRRRRRRRRRRRRR',
#  '\n\n\n\n\n\nEYEYEY:\nSics s qut as que',
#  "\n\n\n\n\nOOOOOOOOOOO Oror Oar', qre",
#  '\n\n\n\n\n\nSSSSSSSSSSSSSSSSSBSSSSSSS',
#  '\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\nOORRECERRRR']

# %% [markdown]
# So it looks terrible. What is happening here? Let's start debugging this by looking at the attention.

# %%
MASTER_CONFIG.update({
    'n_heads': 8,
})
layer = RoPEAttentionHead(MASTER_CONFIG)
batch = torch.ones((MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'], MASTER_CONFIG['d_model']))
output, attn_weights = layer(batch, return_attn_weights=True) # There is no masking, so tokens can attend to future tokens

plt.imshow(attn_weights[0].detach().numpy(), interpolation='nearest')
plt.colorbar()

# %% [markdown]
# So here we see that all the attention is lit up, meaning that characters in any position are attending to characters in any other position. What's bad about this? We are trying to predict the next token *solely* on the tokens that came before it, but here we're seeing that the model is attending to tokens that come after it. In other words, the model is cheating, or leaking information from the future. This is a problem, and it's why we need to use a causal mask.

# %%
config = {
    'batch_size': 10,
    'd_model': 512,
    'n_heads': 8,
    'context_window': 16,
}

class RoPEMaskedAttentionHead(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.w_q = nn.Linear(config['d_model'], config['d_model'], bias=False)
        self.w_k = nn.Linear(config['d_model'], config['d_model'], bias=False)
        self.w_v = nn.Linear(config['d_model'], config['d_model'], bias=False)

        self.R = get_rotary_matrix(config['context_window'], config['d_model'])

    def get_rotary_matrix(context_window, embedding_dim):
        R = torch.zeros((context_window, embedding_dim, embedding_dim), requires_grad=False)
        for position in range(context_window):
            for i in range(embedding_dim//2):
                theta = 10000. ** (-2.*(i - 1) / embedding_dim)
                m_theta = position * theta
                R[position, 2*i,2*i] = np.cos(m_theta)
                R[position, 2*i,2*i+1] = - np.sin(m_theta)
                R[position, 2*i+1,2*i] = np.sin(m_theta)
                R[position, 2*i+1,2*i+1] = np.cos(m_theta)
        return R
    
    def forward(self, x, return_attn_weights=False):
        self.R = self.R.to(x.device)
        b,m,d = x.shape
        
        q = self.w_q(x)
        k = self.w_k(x)
        v = self.w_v(x)

        q_rotated = (torch.bmm(q.transpose(0,1), self.R[:m])).transpose(0,1)
        k_rotated = (torch.bmm(k.transpose(0,1), self.R[:m])).transpose(0,1)

        activations = F.scaled_dot_product_attention(
            q_rotated,k_rotated,v,dropout_p =.1, is_causal=True # this sets the attention mask
        )

        if return_attn_weights:
            attn_mask = torch.tril(torch.ones((m,m)), diagonal=0)
            attn_weights = torch.bmm(q_rotated, k_rotated.transpose(1,2)) / np.sqrt(d) + attn_mask
            attn_weights = F.softmax(attn_weights, dim=-1)
            return activations, attn_weights
        return activations

layer = RoPEMaskedAttentionHead(config)
batch = torch.randn((config['batch_size'], config['context_window'], config['d_model']))
output, attn_weights = layer(batch, return_attn_weights=True)

# %%
layer = RoPEMaskedAttentionHead(MASTER_CONFIG)
batch = torch.ones((MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'], MASTER_CONFIG['d_model']))
output, attn_weights = layer(batch, return_attn_weights=True)

plt.imshow(attn_weights[0].detach().numpy())
plt.colorbar()

# %% [markdown]
# Now, we can see that the upper triangular of our attention activations (the part that corresponds to the future) is nearly zeroed out. Let's see what happens when we train.

# %%
# definitely there's an optimization we could make where we cache the rotation matrices, but skip.
class RoPEMaskedMultiheadAttention(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.heads = nn.ModuleList([
            RoPEMaskedAttentionHead(config) for _ in range(config['n_heads'])
        ])
        self.linear = nn.Linear(config['n_heads'] * config['d_model'], config['d_model'])
        self.dropout = nn.Dropout(.1)

    def forward(self, x):
        heads = [h(x) for h in self.heads]
        x = torch.cat(heads, dim=-1)
        x = self.linear(x)
        x = self.dropout(x)
        return x
    
MASTER_CONFIG.update({
    'n_heads': 8,
})
layer = RoPEMultiheadAttention(MASTER_CONFIG)
batch = torch.ones((MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'], MASTER_CONFIG['d_model']))
output = layer(batch)
output.shape
# Out:
# torch.Size([32, 16, 128])

# %%
class RopeModel(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.embedding = nn.Embedding(config['vocab_size'], config['d_model'])
        self.rms = RMSNorm((config['context_window'], config['d_model']))
        self.rope_attention = RoPEMaskedMultiheadAttention(config)

        self.linear = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            nn.ReLU(),
        )

        self.last_linear = nn.Linear(config['d_model'], config['vocab_size'])
        
        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        
        # one block of attention
        x = self.rms(x) # rms pre-normalization
        x = x + self.rope_attention(x)

        x = self.rms(x) # rms pre-normalization
        x = x + self.linear(x)

        logits = self.last_linear(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1))
            return logits, loss

        else:
            return logits

model = RopeModel(MASTER_CONFIG).to('cuda')
xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])
xs, ys = xs.to('cuda'), ys.to('cuda')

logits, loss = model(xs, ys)
optimizer = torch.optim.Adam(model.parameters())
train(model, optimizer)
# Out:
# model params: 559681
# validation loss:  2.061702477931976
# <Axes: >

# %% [markdown]
# Much better, our loss is now not merely dropping to near-zero. It looks like we can drive our loss down even lower. Let's do that by updating master config.

# %%
MASTER_CONFIG.update({
    "epochs": 5000,
    "log_interval": 10,
})
train(model, optimizer)
# Out:
# validation loss:  1.9353574514389038
# <Axes: >

# %% [markdown]
# ### SwiGLU
#
# As it says in the paper, "We replace the ReLU non-linearity by the SwiGLU activation function...we use a dimension of $\frac{2}{3} 4d$ isntead of $4d$ as in PaLM." SwiGLU is defined as:
# $$
# \text{SwiGLU}(x) = \text{Swish}_\beta (xW + b) \otimes (xV + c)
# $$
# where $\otimes$ is a component-wise product. The Swish function is defined as:
# $$
# \text{Swish}_\beta(x) = x \sigma(\beta x)
# $$
# where $\beta$ is a learnable parameter.

# %%
class SwiGLU(nn.Module):
    """
    Swish-Gated Linear Unit
    https://arxiv.org/pdf/2002.05202v1.pdf
    """
    def __init__(self, size):
        super().__init__()
        self.config = config
        self.linear_gate = nn.Linear(size, size)
        self.linear = nn.Linear(size, size)
        self.beta = torch.randn(1, requires_grad=True)

        self.beta = nn.Parameter(torch.ones(1))
        self.register_parameter("beta", self.beta)

    def forward(self, x): 
        swish_gate = self.linear_gate(x) * torch.sigmoid(self.beta * self.linear_gate(x))
        out = swish_gate * self.linear(x)
        return out

# %%
class RopeModel(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.embedding = nn.Embedding(config['vocab_size'], config['d_model'])
        self.rms = RMSNorm((config['context_window'], config['d_model']))
        self.rope_attention = RoPEMaskedMultiheadAttention(config)

        self.linear = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            SwiGLU(config['d_model']),
        )

        self.last_linear = nn.Linear(config['d_model'], config['vocab_size'])
        
        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embedding(idx)
        
        # one block of attention
        x = self.rms(x) # rms pre-normalization
        x = x + self.rope_attention(x)

        x = self.rms(x) # rms pre-normalization
        x = x + self.linear(x)

        logits = self.last_linear(x)

        if targets is not None:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1))
            return logits, loss

        else:
            return logits

model = RopeModel(MASTER_CONFIG).to('cuda')
xs, ys = get_batches(dataset, 'train', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])
xs, ys = xs.to('cuda'), ys.to('cuda')

logits, loss = model(xs, ys)
optimizer = torch.optim.Adam(model.parameters())
train(model, optimizer)
# Out:
# model params: 592706
# validation loss:  1.9181909203529357
# <Axes: >

# %% [markdown]
# Now, let's add multiple layers of RopeAttention by creating blocks.

# %%
# add RMSNorm and residual conncection
class LlamaBlock(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config

        self.rms = RMSNorm((config['context_window'], config['d_model']))
        
        self.attention = RoPEMaskedMultiheadAttention(config)
        self.feedforward = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            SwiGLU(config['d_model']),
        )

    def forward(self, x):
        x = self.rms(x) # rms pre-normalization
        x = x + self.attention(x)

        x = self.rms(x) # rms pre-normalization
        x = x + self.feedforward(x)
        return x

# %%
block = LlamaBlock(MASTER_CONFIG)
block(torch.randn(MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'], MASTER_CONFIG['d_model']));

# %%
from collections import OrderedDict

MASTER_CONFIG.update({
    'n_layers': 4,
})
class Llama(nn.Module):
    def __init__(self, config):
        super().__init__()
        self.config = config
        self.embeddings = nn.Embedding(config['vocab_size'], config['d_model'])
        self.llama_blocks = nn.Sequential(
            OrderedDict([(f"llama_{i}", LlamaBlock(config)) for i in range(config['n_layers'])])
        )

        self.ffn = nn.Sequential(
            nn.Linear(config['d_model'], config['d_model']),
            SwiGLU(config['d_model']),
            nn.Linear(config['d_model'], config['vocab_size']),
        )

        print("model params:", sum([m.numel() for m in self.parameters()]))

    def forward(self, idx, targets=None):
        x = self.embeddings(idx)
        x = self.llama_blocks(x)
        logits = self.ffn(x)

        if targets is None:
            return logits
        
        else:
            loss = F.cross_entropy(logits.view(-1, self.config['vocab_size']), targets.view(-1))
            return logits, loss

llama = Llama(MASTER_CONFIG).to('cuda')
optimizer = torch.optim.Adam(llama.parameters())
train(llama, optimizer, config=MASTER_CONFIG)
# Out:
# model params: 2370246
# validation loss:  1.6801732659339905
# <Axes: >

# %% [markdown]
# It looks like we can drive the loss down even more, and although we're overfitting a little, I think we can still do better. Let's train longer.

# %%
MASTER_CONFIG.update({
    'epochs': 10000,
})
train(llama, optimizer, scheduler=None, config=MASTER_CONFIG)
# Out:
# validation loss:  1.2939061284065247
# <Axes: >

# %% [markdown]
# It seems we can go even lower, still without serious overfitting. Either there is a leak, or it's actually doing well. The loss here is 1.08, which is equivalent to choosing between 2.9 tokens randomly.

# %%
train(llama, optimizer, config=MASTER_CONFIG)
# Out:
# validation loss:  0.9996801257133484
# <Axes: >

# %%
print(generate(llama, MASTER_CONFIG, 500)[0])
# Out:
# or shell senve: mof I which lopp,
# As to cruuen:
# Haw stral hit her ast ais? Theree?
# LiuSHES HARD:
# Chousen, maush alk appuat
# Wight felow,
# Whose
# Hors clown:
# Where brist Ox fors of his; where mack.
# UE wIO: fae, of raly:
# Nom Moworerfore!
#
# LEONTES:
# Ah me hars they mol, fear;
# BuTHerfle this mode
# For exon what row
# Theses, of frect that wern chowl cheaty
# Edand;
#
# But combs, in his hernor,
#
# Pold,
# Uncless were fror whoe.
#
# QUHET:
#
# SEBTERLANRETETESE:
# I ditumonars
# Whall adoner nor he qlains for.
#
# GRENCE:
# And t

# %% [markdown]
# At this point, we've hit the bottom with our training. Let's test on the test set.

# %%
xs, ys = get_batches(dataset, 'test', MASTER_CONFIG['batch_size'], MASTER_CONFIG['context_window'])
xs, ys = xs.to('cuda'), ys.to('cuda')

logits, loss = llama(xs, ys)

print(loss)
# Out:
# tensor(1.5468, device='cuda:0', grad_fn=<NllLossBackward0>)

# %% [markdown]
# # Miscellaneous

# %% [markdown]
# ## Check for Gradient Flows

# %% [markdown]
# Let's inspect the gradients, we want to see how they're flowing. If there are too many gradients where the value is close to 0, that's a problem.

# %%
# print the percentage that are near 0
def show_grads(model, tol=1e-2):
    return sorted([(name, 100.0 * float(torch.sum(torch.abs(param) <= tol)) / float(param.nelement())) for name, param in model.named_parameters() if param.requires_grad], key=lambda t: t[1], reverse=True)

show_grads(llama)
# Out:
# [('llama_blocks.llama_3.attention.linear.weight', 16.486358642578125),
#  ('llama_blocks.llama_0.attention.linear.weight', 15.13671875),
#  ('llama_blocks.llama_2.attention.linear.weight', 15.05279541015625),
#  ('llama_blocks.llama_1.attention.linear.weight', 15.0146484375),
#  ('llama_blocks.llama_1.attention.heads.2.w_v.weight', 13.0126953125),
#  ('llama_blocks.llama_1.attention.heads.1.w_v.weight', 12.860107421875),
#  ('llama_blocks.llama_3.attention.heads.2.w_v.weight', 12.6953125),
#  ('llama_blocks.llama_1.attention.heads.3.w_v.weight', 12.689208984375),
#  ('llama_blocks.llama_1.attention.heads.6.w_v.weight', 12.59765625),
#  ('llama_blocks.llama_1.attention.heads.0.w_v.weight', 12.469482421875),
#  ('llama_blocks.llama_3.attention.heads.4.w_v.weight', 12.43896484375),
#  ('llama_blocks.llama_0.attention.heads.3.w_v.weight', 12.432861328125),
#  ('llama_blocks.llama_3.attention.heads.5.w_v.weight', 12.420654296875),
#  ('llama_blocks.llama_1.attention.heads.4.w_v.weight', 12.39013671875),
#  ('llama_blocks.llama_1.attention.heads.5.w_v.weight', 12.39013671875),
#  ('llama_blocks.llama_1.attention.heads.7.w_v.weight', 12.3779296875),
#  ('llama_blocks.llama_0.attention.heads.7.w_v.weight', 12.34130859375),
#  ('llama_blocks.llama_3.attention.heads.7.w_v.weight', 12.322998046875),
#  ('llama_blocks.llama_0.attention.heads.6.w_v.weight', 12.310791015625),
#  ('llama_blocks.llama_2.attention.heads.4.w_v.weight', 12.200927734375),
#  ('llama_blocks.llama_2.attention.heads.1.w_v.weight', 12.139892578125),
#  ('llama_blocks.llama_0.attention.heads.4.w_v.weight', 12.127685546875),
#  ('llama_blocks.llama_2.attention.heads.2.w_v.weight', 12.09716796875),
#  ('llama_blocks.llama_2.attention.heads.3.w_v.weight', 12.060546875),
#  ('llama_blocks.llama_3.attention.heads.0.w_v.weight', 12.060546875),
#  ('llama_blocks.llama_0.attention.heads.1.w_v.weight', 11.981201171875),
#  ('llama_blocks.llama_0.attention.heads.0.w_v.weight', 11.968994140625),
#  ('llama_blocks.llama_3.attention.heads.3.w_v.weight', 11.9140625),
#  ('llama_blocks.llama_0.attention.heads.2.w_v.weight', 11.859130859375),
#  ('llama_blocks.llama_3.attention.heads.1.w_v.weight', 11.767578125),
#  ('llama_blocks.llama_2.attention.heads.7.w_v.weight', 11.724853515625),
#  ('llama_blocks.llama_3.attention.heads.6.w_v.weight', 11.68212890625),
#  ('llama_blocks.llama_0.attention.heads.5.w_v.weight', 11.62109375),
#  ('llama_blocks.llama_2.attention.heads.6.w_v.weight', 11.572265625),
#  ('llama_blocks.llama_2.attention.heads.0.w_v.weight', 11.56005859375),
#  ('llama_blocks.llama_2.attention.heads.5.w_v.weight', 11.346435546875),
#  ('llama_blocks.llama_3.attention.heads.4.w_q.weight', 10.272216796875),
#  ('llama_blocks.llama_0.attention.heads.0.w_k.weight', 9.991455078125),
#  ('llama_blocks.llama_0.attention.heads.0.w_q.weight', 9.89990234375),
#  ('llama_blocks.llama_0.attention.heads.4.w_k.weight', 9.893798828125),
#  ('llama_blocks.llama_0.attention.heads.4.w_q.weight', 9.72900390625),
#  ('llama_blocks.llama_0.attention.heads.2.w_q.weight', 9.649658203125),
#  ('llama_blocks.llama_0.attention.heads.6.w_q.weight', 9.625244140625),
#  ('llama_blocks.llama_0.attention.heads.7.w_q.weight', 9.5947265625),
#  ('llama_blocks.llama_3.attention.heads.4.w_k.weight', 9.588623046875),
#  ('llama_blocks.llama_0.attention.heads.5.w_q.weight', 9.564208984375),
#  ('llama_blocks.llama_2.feedforward.0.weight', 9.55810546875),
#  ('llama_blocks.llama_0.attention.heads.2.w_k.weight', 9.478759765625),
#  ('llama_blocks.llama_3.feedforward.0.weight', 9.4482421875),
#  ('llama_blocks.llama_0.attention.heads.6.w_k.weight', 9.41162109375),
#  ('llama_blocks.llama_0.feedforward.0.weight', 9.41162109375),
#  ('llama_blocks.llama_2.feedforward.1.linear_gate.bias', 9.375),
#  ('llama_blocks.llama_3.feedforward.1.linear_gate.bias', 9.375),
#  ('ffn.1.linear_gate.bias', 9.375),
#  ('llama_blocks.llama_0.attention.heads.1.w_q.weight', 9.356689453125),
#  ('llama_blocks.llama_0.attention.heads.5.w_k.weight', 9.3017578125),
#  ('llama_blocks.llama_0.attention.heads.1.w_k.weight', 9.1796875),
#  ('llama_blocks.llama_0.attention.heads.3.w_q.weight', 9.08203125),
#  ('llama_blocks.llama_1.feedforward.0.weight', 9.06982421875),
#  ('llama_blocks.llama_0.attention.heads.3.w_k.weight', 9.0087890625),
#  ('llama_blocks.llama_1.attention.heads.6.w_q.weight', 8.94775390625),
#  ('llama_blocks.llama_3.attention.heads.2.w_q.weight', 8.917236328125),
#  ('llama_blocks.llama_1.attention.heads.6.w_k.weight', 8.89892578125),
#  ('llama_blocks.llama_0.attention.heads.7.w_k.weight', 8.82568359375),
#  ('llama_blocks.llama_2.attention.heads.4.w_k.weight', 8.69140625),
#  ('llama_blocks.llama_3.attention.heads.1.w_q.weight', 8.673095703125),
#  ('llama_blocks.llama_2.attention.heads.4.w_q.weight', 8.660888671875),
#  ('llama_blocks.llama_3.attention.heads.1.w_k.weight', 8.624267578125),
#  ('llama_blocks.llama_1.attention.heads.2.w_q.weight', 8.612060546875),
#  ('llama_blocks.llama_1.attention.heads.1.w_k.weight', 8.60595703125),
#  ('llama_blocks.llama_1.attention.heads.2.w_k.weight', 8.587646484375),
#  ('llama_blocks.llama_3.attention.heads.2.w_k.weight', 8.53271484375),
#  ('llama_blocks.llama_2.attention.heads.3.w_q.weight', 8.447265625),
#  ('llama_blocks.llama_2.attention.heads.1.w_k.weight', 8.31298828125),
#  ('llama_blocks.llama_3.attention.heads.5.w_q.weight', 8.270263671875),
#  ('llama_blocks.llama_1.attention.heads.1.w_q.weight', 8.245849609375),
#  ('llama_blocks.llama_3.attention.heads.3.w_k.weight', 8.245849609375),
#  ('llama_blocks.llama_1.attention.heads.7.w_k.weight', 8.23974609375),
#  ('llama_blocks.llama_1.feedforward.1.linear.weight', 8.233642578125),
#  ('llama_blocks.llama_0.feedforward.1.linear.weight', 8.221435546875),
#  ('llama_blocks.llama_2.attention.heads.3.w_k.weight', 8.21533203125),
#  ('llama_blocks.llama_1.attention.heads.5.w_q.weight', 8.16650390625),
#  ('llama_blocks.llama_3.attention.heads.5.w_k.weight', 8.154296875),
#  ('llama_blocks.llama_0.feedforward.1.linear_gate.weight', 8.135986328125),
#  ('llama_blocks.llama_3.attention.heads.7.w_q.weight', 8.099365234375),
#  ('llama_blocks.llama_3.feedforward.1.linear.weight', 8.04443359375),
#  ('llama_blocks.llama_1.attention.heads.5.w_k.weight', 8.038330078125),
#  ('llama_blocks.llama_3.attention.heads.6.w_q.weight', 8.038330078125),
#  ('llama_blocks.llama_1.attention.heads.3.w_q.weight', 7.97119140625),
#  ('llama_blocks.llama_1.feedforward.1.linear_gate.weight', 7.958984375),
#  ('llama_blocks.llama_3.attention.heads.0.w_q.weight', 7.94677734375),
#  ('llama_blocks.llama_1.attention.heads.7.w_q.weight', 7.92236328125),
#  ('llama_blocks.llama_2.attention.heads.0.w_k.weight', 7.861328125),
#  ('llama_blocks.llama_2.feedforward.1.linear_gate.weight', 7.84912109375),
#  ('llama_blocks.llama_2.attention.heads.0.w_q.weight', 7.830810546875),
#  ('llama_blocks.llama_2.feedforward.1.linear.weight', 7.77587890625),
#  ('llama_blocks.llama_2.attention.heads.7.w_q.weight', 7.769775390625),
#  ('llama_blocks.llama_1.attention.heads.4.w_k.weight', 7.763671875),
#  ('llama_blocks.llama_2.attention.heads.6.w_q.weight', 7.75146484375),
#  ('llama_blocks.llama_2.attention.heads.2.w_k.weight', 7.745361328125),
#  ('llama_blocks.llama_1.attention.heads.4.w_q.weight', 7.72705078125),
#  ('llama_blocks.llama_1.attention.heads.0.w_k.weight', 7.70263671875),
#  ('llama_blocks.llama_3.attention.heads.7.w_k.weight', 7.659912109375),
#  ('llama_blocks.llama_1.attention.heads.3.w_k.weight', 7.65380859375),
#  ('ffn.0.weight', 7.65380859375),
#  ('llama_blocks.llama_3.attention.heads.3.w_q.weight', 7.647705078125),
#  ('llama_blocks.llama_2.attention.heads.1.w_q.weight', 7.635498046875),
#  ('llama_blocks.llama_2.attention.heads.7.w_k.weight', 7.635498046875),
#  ('llama_blocks.llama_1.attention.heads.0.w_q.weight', 7.623291015625),
#  ('llama_blocks.llama_2.attention.heads.6.w_k.weight', 7.562255859375),
#  ('llama_blocks.llama_2.attention.heads.2.w_q.weight', 7.464599609375),
#  ('llama_blocks.llama_3.attention.heads.0.w_k.weight', 7.415771484375),
#  ('llama_blocks.llama_2.attention.heads.5.w_q.weight', 7.38525390625),
#  ('llama_blocks.llama_3.attention.heads.6.w_k.weight', 7.379150390625),
#  ('ffn.1.linear.weight', 7.037353515625),
#  ('llama_blocks.llama_0.feedforward.1.linear_gate.bias', 7.03125),
#  ('llama_blocks.llama_0.feedforward.1.linear.bias', 7.03125),
#  ('llama_blocks.llama_3.feedforward.1.linear.bias', 7.03125),
#  ('ffn.1.linear_gate.weight', 6.92138671875),
#  ('llama_blocks.llama_2.attention.heads.5.w_k.weight', 6.787109375),
#  ('llama_blocks.llama_3.feedforward.1.linear_gate.weight', 6.4453125),
#  ('llama_blocks.llama_2.feedforward.1.linear.bias', 6.25),
#  ('ffn.2.bias', 6.153846153846154),
#  ('ffn.2.weight', 5.264423076923077),
#  ('llama_blocks.llama_0.attention.linear.bias', 4.6875),
#  ('llama_blocks.llama_1.attention.linear.bias', 4.6875),
#  ('llama_blocks.llama_1.feedforward.0.bias', 3.90625),
#  ('llama_blocks.llama_1.feedforward.1.linear_gate.bias', 3.90625),
#  ('llama_blocks.llama_2.attention.linear.bias', 3.90625),
#  ('llama_blocks.llama_3.attention.linear.bias', 3.90625),
#  ('ffn.1.linear.bias', 3.125),
#  ('llama_blocks.llama_0.feedforward.0.bias', 2.34375),
#  ('llama_blocks.llama_1.feedforward.1.linear.bias', 2.34375),
#  ('ffn.0.bias', 2.34375),
#  ('llama_blocks.llama_2.feedforward.0.bias', 1.5625),
#  ('llama_blocks.llama_3.feedforward.0.bias', 1.5625),
#  ('embeddings.weight', 0.9495192307692307),
#  ('llama_blocks.llama_0.rms.scale', 0.09765625),
#  ('llama_blocks.llama_2.rms.scale', 0.048828125),
#  ('llama_blocks.llama_0.feedforward.1.beta', 0.0),
#  ('llama_blocks.llama_1.rms.scale', 0.0),
#  ('llama_blocks.llama_1.feedforward.1.beta', 0.0),
#  ('llama_blocks.llama_2.feedforward.1.beta', 0.0),
#  ('llama_blocks.llama_3.rms.scale', 0.0),
#  ('llama_blocks.llama_3.feedforward.1.beta', 0.0),
#  ('ffn.1.beta', 0.0)]

# %% [markdown]
# Here, for all of our parameter gradients, the vast majority are non-zero, which is great. If we start to see this number peak higher, then our gradients would not be flowing.

# %% [markdown]
# ## Experiment with hyperparams, aka "change the oven settings"
#
# In the original Llama paper, the authors use Cosine Annealing learning schedule. We didn't do that here, because I experimented and saw that it was worse.

# %%
MASTER_CONFIG.update({
    "epochs": 1000
})
llama_with_cosine = Llama(MASTER_CONFIG)
llama_optimizer = torch.optim.Adam(
    llama.parameters(), 
    betas=(.9, .95), 
    weight_decay=.1, 
    eps=1e-9, 
    lr=1e-3
)
scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(llama_optimizer, 300, eta_min=1e-5)
train(llama_with_cosine, llama_optimizer, scheduler=scheduler)

# %%
show_grads(llama_with_cosine, 1e-5)

# %% [markdown]
# Even at an extremely low tolerance, the attention biases are not getting any signal. I'm not sure why the learning schedule from the paper doesn't work, but the lesson here is simple: start simple.
